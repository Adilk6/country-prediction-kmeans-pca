# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
country_data = pd.read_csv('country-data.csv')

# %%
country_data.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
country_data['exports'] = country_data['exports']*country_data['gdpp']/100
country_data['health'] = country_data['health']*country_data['gdpp']/100
country_data['imports'] =country_data['imports']*country_data['gdpp']/100

# %%
country_data['exports'].apply(lambda x:round(x,3))
country_data['health'].apply(lambda x:round(x,3))
country_data['imports'].apply(lambda x:round(x,3))
# Out:
# 0       248.297
# 1      1987.740
# 2      1400.440
# 3      1514.370
# 4      7185.800
#          ...
# 162    1565.190
# 163    2376.000
# 164    1050.620
# 165     450.640
# 166     451.140
# Name: imports, Length: 167, dtype: float64

# %%
country_data.head()
# Out:
#                country  child_mort  exports    health   imports  income  \
# 0          Afghanistan        90.2    55.30   41.9174   248.297    1610
# 1              Albania        16.6  1145.20  267.8950  1987.740    9930
# 2              Algeria        27.3  1712.64  185.9820  1400.440   12900
# 3               Angola       119.0  2199.19  100.6050  1514.370    5900
# 4  Antigua and Barbuda        10.3  5551.00  735.6600  7185.800   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
country_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
country_data.shape
# Out:
# (167, 10)

# %%
country_data.describe
# Out:
# <bound method NDFrame.describe of                  country  child_mort  exports    health   imports  income  \
# 0            Afghanistan        90.2    55.30   41.9174   248.297    1610
# 1                Albania        16.6  1145.20  267.8950  1987.740    9930
# 2                Algeria        27.3  1712.64  185.9820  1400.440   12900
# 3                 Angola       119.0  2199.19  100.6050  1514.370    5900
# 4    Antigua and Barbuda        10.3  5551.00  735.6600  7185.800   19100
# ..                   ...         ...      ...       ...       ...     ...
# 162              Vanuatu        29.2  1384.02  155.9250  1565.190    2950
# 163            Venezuela        17.1  3847.50  662.8500  2376.000   16500
# 164              Vietnam        23.3   943.20   89.6040  1050.620    4490
# 165                Yemen        56.3   393.00   67.8580   450.640    4480
# 166               Zambia        83.1   540.20   85.9940   451.140    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# 1         4.49        76.3       1.65   4090
# 2        16.10        76.5       2.89   4460
# 3        22.40        60.1       6.16   3530
# 4         1.44        76.8       2.13  12200
# ..         ...         ...        ...    ...
# 162       2.62        63.0       3.50   2970
# 163      45.90        75.4       2.47  13500
# 164      12.10        73.1       1.95   1310
# 165      23.60        67.5       4.67   1310
# 166      14.00        52.0       5.40   1460
#
# [167 rows x 10 columns]>

# %%
plt.figure(figsize=(15,10))
feature = country_data.columns[1:10]
for i in enumerate(feature):
    plt.subplot(3,3,i[0]+1)
    sns.distplot(country_data[i[1]])
# Out:
# C:\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(country_data.corr())
plt.title('Heat Map for all features')
plt.show()

# %%
plt.figure(figsize=(10,10))

features = country_data.columns[1:7]
for i in enumerate(features):
    plt.subplot(3,3,i[0]+1)
    sns.boxplot(country_data[i[1]])
# Out:
# C:\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,20), dpi=200)

plt.subplot(3,3,1)
sns.boxplot(x='child_mort', data=country_data)
plt.xlabel('Child Mortality Rate')

plt.subplot(3,3,2)
sns.boxplot(x='exports', data=country_data)
plt.xlabel('Exports')

plt.subplot(3,3,3)
sns.boxplot(x='health', data=country_data)
plt.xlabel('Health')
# Out:
# Text(0.5, 0, 'Health')

# %%
country_data.describe()
# Out:
#        child_mort        exports       health        imports         income  \
# count  167.000000     167.000000   167.000000     167.000000     167.000000
# mean    38.270060    7420.618847  1056.733204    6588.352108   17144.688623
# std     40.328931   17973.885795  1801.408906   14710.810418   19278.067698
# min      2.600000       1.076920    12.821200       0.651092     609.000000
# 25%      8.250000     447.140000    78.535500     640.215000    3355.000000
# 50%     19.300000    1777.440000   321.886000    2045.580000    9960.000000
# 75%     62.100000    7278.000000   976.940000    7719.600000   22800.000000
# max    208.000000  183750.000000  8663.600000  149100.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# 50%      5.390000   73.100000    2.410000    4660.000000
# 75%     10.750000   76.800000    3.880000   14050.000000
# max    104.000000   82.800000    7.490000  105000.000000

# %%
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
import numpy as np
from math import isnan
 
def hopkins(X):
    d = X.shape[1]
    #d = len(vars) # columns
    n = len(X) # rows
    m = int(0.1 * n) 
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)
 
    rand_X = sample(range(0, n, 1), m)
    
   ujd = []
   wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])
 
    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0
 
    return H
# Out:
#   File "<tokenize>", line 16
#     ujd = []
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
hopkins(country_data.drop('country',axis=1))

# %%
country_data1 = country_data.drop('country',axis=1)
country_data1.head()
# Out:
#    child_mort  exports    health   imports  income  inflation  life_expec  \
# 0        90.2    55.30   41.9174   248.297    1610       9.44        56.2
# 1        16.6  1145.20  267.8950  1987.740    9930       4.49        76.3
# 2        27.3  1712.64  185.9820  1400.440   12900      16.10        76.5
# 3       119.0  2199.19  100.6050  1514.370    5900      22.40        60.1
# 4        10.3  5551.00  735.6600  7185.800   19100       1.44        76.8
#
#    total_fer   gdpp
# 0       5.82    553
# 1       1.65   4090
# 2       2.89   4460
# 3       6.16   3530
# 4       2.13  12200

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
ss = []
for k in range(2,11):
    kmeans = KMeans(n_clusters=k).fit(country_data1)
    ss.append([k,silhouette_score(country_data1,kmeans.labels_)])
temp = pd.DataFrame(ss)
plt.plot(temp[0],temp[1])

# %%
ssd = []
for k in range(2,10):
    kmean = KMeans(n_clusters=k).fit(country_data1)
    ssd.append([k,kmean.inertia_])
temp = pd.DataFrame(ssd)
plt.plot(temp[0],temp[1])

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

plt.figure(figsize=(15,15))

plt.subplot(2,2,1)
sns.scatterplot(x='child_mort', y='income', hue='labels', data=country_data.kmean, palette='Set1')
plt.title('Child_mort vs Income')

plt.subplot(2,2,2)
sns.scatterplot(x='child_mort', y='gdpp', hue='labels', data=country_data.kmean, palette='Set1')
plt.title('Child_mort vs GDPP')

plt.subplot(2,2,3)
sns.scatterplot(x='income', y='gdpp', hue='labels', data=country_data.kmean, palette='Set1')
plt.title('Income vs GDPP')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19120/1321959150.py in <module>
#       5
#       6 plt.subplot(2,2,1)
# ----> 7 sns.scatterplot(x='child_mort', y='income', hue='labels', data=country_data.kmean, palette='Set1')
#       8 plt.title('Child_mort vs Income')
#       9
#
# C:\Python\Python310\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'kmean'

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
sns.boxplot(x='labels',y='child_mort',data=country_data.kmean)

plt.subplot(2,2,2)
sns.boxplot(x='labels',y='income',data=country_data.kmean)

plt.subplot(2,2,3)
sns.boxplot(x='labels',y='gdpp',data=country_data.kmean)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19120/3734394887.py in <module>
#       2
#       3 plt.subplot(2,2,1)
# ----> 4 sns.boxplot(x='labels',y='child_mort',data=country_data.kmean)
#       5
#       6 plt.subplot(2,2,2)
#
# C:\Python\Python310\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'kmean'

# %%
#silhoutte score
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
ss = []
for k in range(2,11):
    kmeans = KMeans(n_clusters=k).fit(country_data1)
    ss.append([k,silhouette_score(country_data1,kmeans.labels_)])
temp = pd.DataFrame(ss)
plt.plot(temp[0],temp[1])

# %%
range_n_cluster = [2,3,4,5,6,7,8]

for num_clusters in range_n_cluster:
    
    #initialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(country_data1)
    
    cluster_labels = kmeans.labels_
    
    #silhouette score
    silhouette_avg = silhouette_score(country_data1,cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters,silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.712586926709893
# For n_clusters=3, the silhouette score is 0.7010999403856036
# For n_clusters=4, the silhouette score is 0.6876753336765676
# For n_clusters=5, the silhouette score is 0.5759947109927962
# For n_clusters=6, the silhouette score is 0.5314887374931582
# For n_clusters=7, the silhouette score is 0.5391498956530251
# For n_clusters=8, the silhouette score is 0.5316351075828922

# %%
#k=3
kmean = KMeans(n_clusters = 3,random_state=101)
kmean.fit(country_data1)
# Out:
# KMeans(n_clusters=3, random_state=101)

# %%
label = pd.DataFrame(kmean.labels_, columns = ['labels'])
country_data.kmean = country_data.copy()
country_data.kmean = pd.concat([country_data.kmean,label],axis=1)
country_data.kmean.head()
# Out:
# C:\Users\AD\AppData\Local\Temp/ipykernel_19120/57227389.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   country_data.kmean = country_data.copy()
#                country  child_mort  exports    health   imports  income  \
# 0          Afghanistan        90.2    55.30   41.9174   248.297    1610
# 1              Albania        16.6  1145.20  267.8950  1987.740    9930
# 2              Algeria        27.3  1712.64  185.9820  1400.440   12900
# 3               Angola       119.0  2199.19  100.6050  1514.370    5900
# 4  Antigua and Barbuda        10.3  5551.00  735.6600  7185.800   19100
#
#    inflation  life_expec  total_fer   gdpp  labels
# 0       9.44        56.2       5.82    553       0
# 1       4.49        76.3       1.65   4090       0
# 2      16.10        76.5       2.89   4460       0
# 3      22.40        60.1       6.16   3530       0
# 4       1.44        76.8       2.13  12200       0

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,4)
sns.scatterplot(x='child_mort', y='income', hue='labels', data=country_data.kmean, palette='Set2')
plt.title('Child_mort vs Income')

plt.subplot(2,2,2)
sns.scatterplot(x='child_mort', y='gdpp', hue='labels', data=country_data.kmean, palette='Set2')
plt.title('Child_mort vs GDPP')

plt.subplot(2,2,3)
sns.scatterplot(x='income', y='gdpp', hue='labels', data=country_data.kmean, palette='Set2')
plt.title('Income vs GDPP')

plt.show()

# %% [markdown]
# ###

# %%
country_data.kmean.drop(['country', 'exports', 'health', 'imports','inflation', 'life_expec', 'total_fer'],axis=1).groupby('labels').mean()
# Out:
#         child_mort        income          gdpp
# labels
# 0        47.052713   8713.666667   4578.403101
# 1         2.800000  81900.000000  75800.000000
# 2         8.769444  43758.333333  39522.222222

# %%
plt.figure(figsize=(10,10))

country_data.kmean.drop(['country','exports','health','imports','inflation','life_expec','total_fer'],axis=1).groupby('labels').mean().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.boxplot(x='labels',y='child_mort',data=country_data.kmean)

plt.subplot(2,2,2)
sns.boxplot(x='labels',y='income',data=country_data.kmean)

plt.subplot(2,2,3)
sns.boxplot(x='labels',y='gdpp',data=country_data.kmean)

plt.show()
